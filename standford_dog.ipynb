# %% [markdown]
# # Import libraries

# %%
import tensorflow as tf
import numpy as np
import collections
import pathlib
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras import Model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.utils import to_categorical, model_to_dot, plot_model
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
# Out:
# 2023-04-04 14:49:38.994220: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 14:49:39.518929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Transfer Learning via VVG19 and InceptionV3
# ## 1.VGG19
# #### 1.1 Load dataset

# %%
dataset_url = "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar"
archive = tf.keras.utils.get_file(origin=dataset_url, extract=True)
data_dir = pathlib.Path(archive).with_suffix('')

# %% [markdown]
# #### 1.2  Data Preprocessing

# %%
data_dir = "Images/"  ## Dataset directory
img_width, img_height = 224, 224 
channels = 3
batch_size = 64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20580 files belonging to 120 classes.
# Using 16464 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20580 files belonging to 120 classes.
# Using 4116 files for validation.

# %%
class_names = train_ds.class_names ### classes' name

# %%
classes = []
for name in class_names:
    classes.append(name.split('-')[1])  ### To collect all classes' name in one list

# %%
classes
# Out:
# ['Chihuahua',
#  'Japanese_spaniel',
#  'Maltese_dog',
#  'Pekinese',
#  'Shih',
#  'Blenheim_spaniel',
#  'papillon',
#  'toy_terrier',
#  'Rhodesian_ridgeback',
#  'Afghan_hound',
#  'basset',
#  'beagle',
#  'bloodhound',
#  'bluetick',
#  'black',
#  'Walker_hound',
#  'English_foxhound',
#  'redbone',
#  'borzoi',
#  'Irish_wolfhound',
#  'Italian_greyhound',
#  'whippet',
#  'Ibizan_hound',
#  'Norwegian_elkhound',
#  'otterhound',
#  'Saluki',
#  'Scottish_deerhound',
#  'Weimaraner',
#  'Staffordshire_bullterrier',
#  'American_Staffordshire_terrier',
#  'Bedlington_terrier',
#  'Border_terrier',
#  'Kerry_blue_terrier',
#  'Irish_terrier',
#  'Norfolk_terrier',
#  'Norwich_terrier',
#  'Yorkshire_terrier',
#  'wire',
#  'Lakeland_terrier',
#  'Sealyham_terrier',
#  'Airedale',
#  'cairn',
#  'Australian_terrier',
#  'Dandie_Dinmont',
#  'Boston_bull',
#  'miniature_schnauzer',
#  'giant_schnauzer',
#  'standard_schnauzer',
#  'Scotch_terrier',
#  'Tibetan_terrier',
#  'silky_terrier',
#  'soft',
#  'West_Highland_white_terrier',
#  'Lhasa',
#  'flat',
#  'curly',
#  'golden_retriever',
#  'Labrador_retriever',
#  'Chesapeake_Bay_retriever',
#  'German_short',
#  'vizsla',
#  'English_setter',
#  'Irish_setter',
#  'Gordon_setter',
#  'Brittany_spaniel',
#  'clumber',
#  'English_springer',
#  'Welsh_springer_spaniel',
#  'cocker_spaniel',
#  'Sussex_spaniel',
#  'Irish_water_spaniel',
#  'kuvasz',
#  'schipperke',
#  'groenendael',
#  'malinois',
#  'briard',
#  'kelpie',
#  'komondor',
#  'Old_English_sheepdog',
#  'Shetland_sheepdog',
#  'collie',
#  'Border_collie',
#  'Bouvier_des_Flandres',
#  'Rottweiler',
#  'German_shepherd',
#  'Doberman',
#  'miniature_pinscher',
#  'Greater_Swiss_Mountain_dog',
#  'Bernese_mountain_dog',
#  'Appenzeller',
#  'EntleBucher',
#  'boxer',
#  'bull_mastiff',
#  'Tibetan_mastiff',
#  'French_bulldog',
#  'Great_Dane',
#  'Saint_Bernard',
#  'Eskimo_dog',
#  'malamute',
#  'Siberian_husky',
#  'affenpinscher',
#  'basenji',
#  'pug',
#  'Leonberg',
#  'Newfoundland',
#  'Great_Pyrenees',
#  'Samoyed',
#  'Pomeranian',
#  'chow',
#  'keeshond',
#  'Brabancon_griffon',
#  'Pembroke',
#  'Cardigan',
#  'toy_poodle',
#  'miniature_poodle',
#  'standard_poodle',
#  'Mexican_hairless',
#  'dingo',
#  'dhole',
#  'African_hunting_dog']

# %% [markdown]
# #### 1.3 Visualization

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(classes[labels[i]])
        plt.axis("off")
# Out:
# 2023-04-04 14:50:13.631022: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [16464]
# 	 [[{{node Placeholder/_4}}]]
# 2023-04-04 14:50:13.631678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [16464]
# 	 [[{{node Placeholder/_0}}]]

# %%
for image_batch, labels_batch in train_ds:  ### Show image_batch's and labels_batch's shape
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 224, 224, 3)
# (64,)

# %% [markdown]
# #### 1.4 Normalization

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
### normalized_train_ds
normalized_train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_train_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0
# 2023-04-04 14:50:23.482627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [16464]
# 	 [[{{node Placeholder/_4}}]]
# 2023-04-04 14:50:23.482833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [16464]
# 	 [[{{node Placeholder/_4}}]]

# %%
### normalized_val_ds
normalized_val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_val_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.9665008
# 2023-04-04 14:50:27.657060: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [4116]
# 	 [[{{node Placeholder/_4}}]]
# 2023-04-04 14:50:27.657286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [4116]
# 	 [[{{node Placeholder/_4}}]]

# %% [markdown]
# #### 1.5 To build the model via VGG19

# %%
vgg19 = tf.keras.applications.vgg19.VGG19(include_top = False, input_shape = (img_width, img_height, channels), weights = 'imagenet')
vgg19.summary()  ### To show the model's architecture
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 20s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_vgg19 = Sequential()
for layer in vgg19.layers:
    layer.trainable = False      ### To turn off VGG19's trainable parameters
model_vgg19.add(vgg19)
model_vgg19.add(Flatten())      
model_vgg19.add(Dense(4096, activation = 'relu'))
model_vgg19.add(Dropout(0.2))
model_vgg19.add(Dense(1024, activation = 'relu'))
model_vgg19.add(Dense(120, activation = 'softmax'))
model_vgg19.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 1024)              4195328
#
#  dense_2 (Dense)             (None, 120)               123000
#
# =================================================================
# Total params: 127,107,256
# Trainable params: 107,082,872
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# To select the optimizer and the loss
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)    
optimizer = tf.keras.optimizers.Adam()

# %%
# Compile the model
model_vgg19.compile(optimizer=optimizer, loss=loss_object, metrics=['accuracy'])

# %% [markdown]
# #### 1.6 Callbacks

# %%
checkpoint = ModelCheckpoint(
    'model_vgg19.h5',
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    period=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=3,
    verbose=1,
    mode='auto'
)
csvlogger = CSVLogger(
    filename= "training_csv.log",
    separator = ",",
    append = False
)
reduceLR = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3,
    verbose=1, 
    mode='auto'
)
callbacks = [checkpoint, earlystop, csvlogger,reduceLR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
### To fit the model
history = model_vgg19.fit(
    normalized_train_ds, 
    epochs = 10,
    validation_data = normalized_val_ds, 
    callbacks = callbacks,
    shuffle = True
)
# Out:
# Epoch 1/10
# /home/airi/anaconda3/envs/tf/lib/python3.9/site-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 2023-04-04 14:52:53.673569: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-04-04 14:52:54.119988: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-04-04 14:52:54.122077: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2023-04-04 14:52:54.122106: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2023-04-04 14:52:54.122207: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:317] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-04-04 14:52:56.112477: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-04 14:52:56.131178: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x539d3cc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-04 14:52:56.131208: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2023-04-04 14:52:56.131215: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2023-04-04 14:52:56.137002: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-04 14:52:56.190554: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-04-04 14:52:56.213977: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-04-04 14:52:56.267902: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-04-04 14:52:56.339476: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-04-04 14:52:56.419035: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-04-04 14:52:56.493119: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#   1/258 [..............................] - ETA: 19:23 - loss: 5.0039 - accuracy: 0.0312
# 2023-04-04 14:52:56.570602: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
# 258/258 [==============================] - ETA: 0s - loss: 5.1680 - accuracy: 0.0342
# Epoch 1: val_loss improved from inf to 3.89822, saving model to model_vgg19.h5
# 258/258 [==============================] - 76s 279ms/step - loss: 5.1680 - accuracy: 0.0342 - val_loss: 3.8982 - val_accuracy: 0.0904 - lr: 0.0010
# Epoch 2/10
# 258/258 [==============================] - ETA: 0s - loss: 3.6817 - accuracy: 0.1215
# Epoch 2: val_loss improved from 3.89822 to 3.45552, saving model to model_vgg19.h5
# 258/258 [==============================] - 71s 276ms/step - loss: 3.6817 - accuracy: 0.1215 - val_loss: 3.4555 - val_accuracy: 0.1475 - lr: 0.0010
# Epoch 3/10
# 258/258 [==============================] - ETA: 0s - loss: 3.2320 - accuracy: 0.1845
# Epoch 3: val_loss improved from 3.45552 to 3.26226, saving model to model_vgg19.h5
# 258/258 [==============================] - 71s 274ms/step - loss: 3.2320 - accuracy: 0.1845 - val_loss: 3.2623 - val_accuracy: 0.1893 - lr: 0.0010
# Epoch 4/10
# 258/258 [==============================] - ETA: 0s - loss: 2.8821 - accuracy: 0.2471
# Epoch 4: val_loss improved from 3.26226 to 3.17595, saving model to model_vgg19.h5
# 258/258 [==============================] - 71s 274ms/step - loss: 2.8821 - accuracy: 0.2471 - val_loss: 3.1760 - val_accuracy: 0.2051 - lr: 0.0010
# Epoch 5/10
# 258/258 [==============================] - ETA: 0s - loss: 2.6039 - accuracy: 0.3022
# Epoch 5: val_loss improved from 3.17595 to 3.11583, saving model to model_vgg19.h5
# 258/258 [==============================] - 71s 275ms/step - loss: 2.6039 - accuracy: 0.3022 - val_loss: 3.1158 - val_accuracy: 0.2259 - lr: 0.0010
# Epoch 6/10
# 258/258 [==============================] - ETA: 0s - loss: 2.3249 - accuracy: 0.3582
# Epoch 6: val_loss did not improve from 3.11583
# 258/258 [==============================] - 69s 269ms/step - loss: 2.3249 - accuracy: 0.3582 - val_loss: 3.1451 - val_accuracy: 0.2366 - lr: 0.0010
# Epoch 7/10
# 258/258 [==============================] - ETA: 0s - loss: 2.1004 - accuracy: 0.4063
# Epoch 7: val_loss did not improve from 3.11583
# 258/258 [==============================] - 70s 270ms/step - loss: 2.1004 - accuracy: 0.4063 - val_loss: 3.2897 - val_accuracy: 0.2306 - lr: 0.0010
# Epoch 8/10
# 258/258 [==============================] - ETA: 0s - loss: 1.8629 - accuracy: 0.4673
# Epoch 8: val_loss did not improve from 3.11583
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 258/258 [==============================] - 70s 271ms/step - loss: 1.8629 - accuracy: 0.4673 - val_loss: 3.3573 - val_accuracy: 0.2434 - lr: 0.0010
# Epoch 8: early stopping

# %% [markdown]
# #### 1.7 Load the model

# %%
load_model_vgg19 = tf.keras.models.load_model('model_vgg19.h5')

# %% [markdown]
# #### 1.8 Evaluate the model

# %%
test_loss, test_accuracy = load_model_vgg19.evaluate(normalized_val_ds)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
# Out:
# 65/65 [==============================] - 13s 197ms/step - loss: 3.1158 - accuracy: 0.2259
# Test Loss: 3.115830421447754, Test Accuracy: 0.2259475290775299

# %% [markdown]
# ## 2.InceptionV3

# %% [markdown]
# #### 2.1  Data Preprocessing - ImageDataGenerator and Data Augmentation

# %%
data_dir = "Images/"  ## Dataset directory
img_width, img_height = 224, 224 
channels = 3
batch_size = 64

# %%
train_datagen = ImageDataGenerator(
    rescale= 1./255, # Normalization
    shear_range= 0.2,
    zoom_range= 0.2,
    horizontal_flip= True,
    rotation_range= 20,
    width_shift_range= 0.2,
    height_shift_range= 0.2,   
    validation_split=0.2,

)
valid_datagen = ImageDataGenerator(
    rescale= 1./255, # Normalization
    validation_split=0.2,
)

# %%
train_generator = train_datagen.flow_from_directory(  
    data_dir,  
    target_size= (img_width, img_height), 
    color_mode= 'rgb',
    batch_size= batch_size,  
    class_mode= 'categorical',
    subset='training',
    shuffle= True, 
    seed= 1337
)
# Out:
# Found 16508 images belonging to 120 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(
    data_dir,
    target_size= (img_width, img_height),
    color_mode= 'rgb',
    batch_size= batch_size,  
    class_mode= 'categorical',
    subset='validation',
    shuffle= True, 
    seed= 1337
)
# Out:
# Found 4072 images belonging to 120 classes.

# %%
num_classes = len(train_generator.class_indices)  
train_labels = train_generator.classes 
train_labels = to_categorical(train_labels, num_classes=num_classes)
valid_labels = valid_generator.classes 
valid_labels = to_categorical(valid_labels, num_classes=num_classes)
nb_train_samples = len(train_generator.filenames)  
nb_valid_samples = len(valid_generator.filenames)

# %% [markdown]
# #### 2.2 To build the model via InceptionV3

# %%
InceptionV3 = tf.keras.applications.InceptionV3(include_top= False, input_shape= (img_width, img_height, channels), weights= 'imagenet')
InceptionV3.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 24s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_188 (Conv2D)            (None, 111, 111, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 111, 111, 32  96         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  activation_188 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 109, 109, 32  9216        ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 109, 109, 32  96         ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  activation_189 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_189[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 109, 109, 64  18432       ['activation_189[0][0]']
#                                 )
#
#  batch_normalization_190 (Batch  (None, 109, 109, 64  192        ['conv2d_190[0][0]']
#  Normalization)                 )
#
#  activation_190 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 54, 54, 64)  0           ['activation_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (Batch  (None, 54, 54, 80)  240         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 52, 52, 192)  576        ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_192[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_192[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (Batch  (None, 25, 25, 64)  192         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_196[0][0]']
#
#  batch_normalization_194 (Batch  (None, 25, 25, 48)  144         ['conv2d_194[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 25, 25, 96)  288         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_194[0][0]']
#
#  activation_197 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_197[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_9[0][0]']
#  ooling2D)
#
#  conv2d_193 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_197[0][0]']
#  conv2d_199 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (Batch  (None, 25, 25, 64)  192         ['conv2d_193[0][0]']
#  Normalization)
#
#  batch_normalization_195 (Batch  (None, 25, 25, 64)  192         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 25, 25, 96)  288         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_199 (Batch  (None, 25, 25, 32)  96          ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_193[0][0]']
#
#  activation_195 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_198[0][0]']
#
#  activation_199 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_199[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_193[0][0]',
#                                                                   'activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_203 (Batch  (None, 25, 25, 64)  192         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_203[0][0]']
#
#  batch_normalization_201 (Batch  (None, 25, 25, 48)  144         ['conv2d_201[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 25, 25, 96)  288         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_201[0][0]']
#
#  activation_204 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_204[0][0]']
#
#  average_pooling2d_19 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_200 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (Batch  (None, 25, 25, 64)  192         ['conv2d_200[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 25, 25, 64)  192         ['conv2d_202[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 25, 25, 96)  288         ['conv2d_205[0][0]']
#  Normalization)
#
#  batch_normalization_206 (Batch  (None, 25, 25, 64)  192         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_200[0][0]']
#
#  activation_202 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_202[0][0]']
#
#  activation_205 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_205[0][0]']
#
#  activation_206 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_206[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_200[0][0]',
#                                                                   'activation_202[0][0]',
#                                                                   'activation_205[0][0]',
#                                                                   'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_210 (Batch  (None, 25, 25, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_210[0][0]']
#
#  batch_normalization_208 (Batch  (None, 25, 25, 48)  144         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 25, 25, 96)  288         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_208[0][0]']
#
#  activation_211 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_211[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_207 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (Batch  (None, 25, 25, 64)  192         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_209 (Batch  (None, 25, 25, 64)  192         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 25, 25, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 25, 25, 64)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_207[0][0]']
#
#  activation_209 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_212[0][0]']
#
#  activation_213 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_213[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_207[0][0]',
#                                                                   'activation_209[0][0]',
#                                                                   'activation_212[0][0]',
#                                                                   'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_215 (Batch  (None, 25, 25, 64)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_215[0][0]']
#
#  batch_normalization_216 (Batch  (None, 25, 25, 96)  288         ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_216[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_216[0][0]']
#
#  batch_normalization_214 (Batch  (None, 12, 12, 384)  1152       ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 12, 12, 96)  288         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_214[0][0]']
#
#  activation_217 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_217[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_214[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_222 (Batch  (None, 12, 12, 128)  384        ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 12, 12, 128)  384        ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_223[0][0]']
#
#  batch_normalization_219 (Batch  (None, 12, 12, 128)  384        ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 12, 12, 128)  384        ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_219[0][0]']
#
#  activation_224 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_224[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_224[0][0]']
#
#  batch_normalization_220 (Batch  (None, 12, 12, 128)  384        ['conv2d_220[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 12, 12, 128)  384        ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_220[0][0]']
#
#  activation_225 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_225[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_218 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (Batch  (None, 12, 12, 192)  576        ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 12, 12, 192)  576        ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 12, 12, 192)  576        ['conv2d_226[0][0]']
#  Normalization)
#
#  batch_normalization_227 (Batch  (None, 12, 12, 192)  576        ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_218[0][0]']
#
#  activation_221 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_221[0][0]']
#
#  activation_226 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_226[0][0]']
#
#  activation_227 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_227[0][0]']
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_218[0][0]',
#                                                                   'activation_221[0][0]',
#                                                                   'activation_226[0][0]',
#                                                                   'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_232 (Batch  (None, 12, 12, 160)  480        ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_232[0][0]']
#
#  batch_normalization_233 (Batch  (None, 12, 12, 160)  480        ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_233[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_233[0][0]']
#
#  batch_normalization_229 (Batch  (None, 12, 12, 160)  480        ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 12, 12, 160)  480        ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_229[0][0]']
#
#  activation_234 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_234[0][0]']
#
#  batch_normalization_230 (Batch  (None, 12, 12, 160)  480        ['conv2d_230[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 12, 12, 160)  480        ['conv2d_235[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_230[0][0]']
#
#  activation_235 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_235[0][0]']
#
#  average_pooling2d_22 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_228 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (Batch  (None, 12, 12, 192)  576        ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 12, 12, 192)  576        ['conv2d_231[0][0]']
#  Normalization)
#
#  batch_normalization_236 (Batch  (None, 12, 12, 192)  576        ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 12, 12, 192)  576        ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_231[0][0]']
#
#  activation_236 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_236[0][0]']
#
#  activation_237 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_237[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_228[0][0]',
#                                                                   'activation_231[0][0]',
#                                                                   'activation_236[0][0]',
#                                                                   'activation_237[0][0]']
#  conv2d_242 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_242 (Batch  (None, 12, 12, 160)  480        ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_242[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_242[0][0]']
#
#  batch_normalization_243 (Batch  (None, 12, 12, 160)  480        ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 12, 12, 160)  480        ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 12, 12, 160)  480        ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_239[0][0]']
#
#  activation_244 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_244[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_239[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_244[0][0]']
#
#  batch_normalization_240 (Batch  (None, 12, 12, 160)  480        ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_245 (Batch  (None, 12, 12, 160)  480        ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_240[0][0]']
#
#  activation_245 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_245[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_238 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_240[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_245[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_238 (Batch  (None, 12, 12, 192)  576        ['conv2d_238[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 12, 12, 192)  576        ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 12, 12, 192)  576        ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 12, 12, 192)  576        ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_238[0][0]']
#
#  activation_241 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_241[0][0]']
#
#  activation_246 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_246[0][0]']
#
#  activation_247 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_247[0][0]']
# ...
#
#  mixed8 (Concatenate)           (None, 5, 5, 1280)   0           ['activation_259[0][0]',
#                                                                   'activation_263[0][0]',
#                                                                   'max_pooling2d_11[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 5, 5, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_268 (Batch  (None, 5, 5, 448)   1344        ['conv2d_268[0][0]']
#  Normalization)
#
#  activation_268 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_268[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_268[0][0]']
#
#  batch_normalization_265 (Batch  (None, 5, 5, 384)   1152        ['conv2d_265[0][0]']
#  Normalization)
#
#  batch_normalization_269 (Batch  (None, 5, 5, 384)   1152        ['conv2d_269[0][0]']
#  Normalization)
#
#  activation_265 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_265[0][0]']
#
#  activation_269 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_269[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_265[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_265[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_269[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_269[0][0]']
#
#  average_pooling2d_25 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_264 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_266 (Batch  (None, 5, 5, 384)   1152        ['conv2d_266[0][0]']
#  Normalization)
#
#  batch_normalization_267 (Batch  (None, 5, 5, 384)   1152        ['conv2d_267[0][0]']
#  Normalization)
#
#  batch_normalization_270 (Batch  (None, 5, 5, 384)   1152        ['conv2d_270[0][0]']
#  Normalization)
#
#  batch_normalization_271 (Batch  (None, 5, 5, 384)   1152        ['conv2d_271[0][0]']
#  Normalization)
#
#  conv2d_272 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_25[0][0]']
#
#  batch_normalization_264 (Batch  (None, 5, 5, 320)   960         ['conv2d_264[0][0]']
#  Normalization)
#
#  activation_266 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_266[0][0]']
#
#  activation_267 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_267[0][0]']
#
#  activation_270 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_270[0][0]']
#
#  activation_271 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_271[0][0]']
#
#  batch_normalization_272 (Batch  (None, 5, 5, 192)   576         ['conv2d_272[0][0]']
#  Normalization)
#
#  activation_264 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_264[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_266[0][0]',
#                                                                   'activation_267[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 5, 5, 768)    0           ['activation_270[0][0]',
#                                                                   'activation_271[0][0]']
#
#  activation_272 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_272[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_264[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'activation_272[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_277 (Batch  (None, 5, 5, 448)   1344        ['conv2d_277[0][0]']
#  Normalization)
#
#  activation_277 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_277[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_277[0][0]']
#
#  batch_normalization_274 (Batch  (None, 5, 5, 384)   1152        ['conv2d_274[0][0]']
#  Normalization)
#
#  batch_normalization_278 (Batch  (None, 5, 5, 384)   1152        ['conv2d_278[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_274[0][0]']
#
#  activation_278 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_278[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_274[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_274[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_278[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_278[0][0]']
#
#  average_pooling2d_26 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_273 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_275 (Batch  (None, 5, 5, 384)   1152        ['conv2d_275[0][0]']
#  Normalization)
#
#  batch_normalization_276 (Batch  (None, 5, 5, 384)   1152        ['conv2d_276[0][0]']
#  Normalization)
#
#  batch_normalization_279 (Batch  (None, 5, 5, 384)   1152        ['conv2d_279[0][0]']
#  Normalization)
#
#  batch_normalization_280 (Batch  (None, 5, 5, 384)   1152        ['conv2d_280[0][0]']
#  Normalization)
#
#  conv2d_281 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_26[0][0]']
#
#  batch_normalization_273 (Batch  (None, 5, 5, 320)   960         ['conv2d_273[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_275[0][0]']
#
#  activation_276 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_276[0][0]']
#
#  activation_279 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_279[0][0]']
#
#  activation_280 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_280[0][0]']
#
#  batch_normalization_281 (Batch  (None, 5, 5, 192)   576         ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_273 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_273[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_275[0][0]',
#                                                                   'activation_276[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 5, 5, 768)    0           ['activation_279[0][0]',
#                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_281[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_273[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'activation_281[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
model_InceptionV3 = Sequential()

for layer in InceptionV3.layers:
    layer.trainable= False
    
model_InceptionV3.add(InceptionV3)
model_InceptionV3.add(GlobalAveragePooling2D())
model_InceptionV3.add(Dropout(0.2))
model_InceptionV3.add(Dense(120,activation='softmax'))
model_InceptionV3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  global_average_pooling2d_3   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 120)               245880
#
# =================================================================
# Total params: 22,048,664
# Trainable params: 245,880
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# Compile the model
model_InceptionV3.compile(optimizer=tf.keras.optimizers.Adam(lr= 0.0001), loss= 'categorical_crossentropy', metrics= ['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# #### 2.3 Callbacks

# %%
checkpoint = ModelCheckpoint(
    'model_InceptionV3.h5',
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    period=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=3,
    verbose=1,
    mode='auto'
)
csvlogger = CSVLogger(
    filename= "training_InceptionV3_csv.log",
    separator = ",",
    append = False
)
reduceLR = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3,
    verbose=1, 
    mode='auto'
)
callbacks = [checkpoint, earlystop, csvlogger,reduceLR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
### To fit the model
history = model_InceptionV3.fit(
    train_generator, 
    epochs = 10,
    steps_per_epoch = nb_train_samples//batch_size,
    validation_data = valid_generator, 
    validation_steps = nb_valid_samples//batch_size,
    verbose = 2, 
    callbacks = callbacks,
    shuffle = True
)
# Out:
# Epoch 1/10
# 2023-04-04 15:39:05.709877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-04-04 15:40:56.683257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.78149, saving model to model_InceptionV3.h5
# 257/257 - 117s - loss: 1.5187 - accuracy: 0.6165 - val_loss: 0.7815 - val_accuracy: 0.7763 - lr: 0.0010 - 117s/epoch - 456ms/step
# Epoch 2/10
#
# Epoch 2: val_loss improved from 0.78149 to 0.76183, saving model to model_InceptionV3.h5
# 257/257 - 115s - loss: 0.9922 - accuracy: 0.7245 - val_loss: 0.7618 - val_accuracy: 0.7842 - lr: 0.0010 - 115s/epoch - 446ms/step
# Epoch 3/10
#
# Epoch 3: val_loss improved from 0.76183 to 0.75636, saving model to model_InceptionV3.h5
# 257/257 - 114s - loss: 0.9272 - accuracy: 0.7370 - val_loss: 0.7564 - val_accuracy: 0.7914 - lr: 0.0010 - 114s/epoch - 445ms/step
# Epoch 4/10
#
# Epoch 4: val_loss did not improve from 0.75636
# 257/257 - 114s - loss: 0.8944 - accuracy: 0.7468 - val_loss: 0.8072 - val_accuracy: 0.7845 - lr: 0.0010 - 114s/epoch - 444ms/step
# Epoch 5/10
#
# Epoch 5: val_loss did not improve from 0.75636
# 257/257 - 114s - loss: 0.8535 - accuracy: 0.7513 - val_loss: 0.8693 - val_accuracy: 0.7696 - lr: 0.0010 - 114s/epoch - 445ms/step
# Epoch 6/10
#
# Epoch 6: val_loss did not improve from 0.75636
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 257/257 - 114s - loss: 0.8199 - accuracy: 0.7609 - val_loss: 0.7842 - val_accuracy: 0.7862 - lr: 0.0010 - 114s/epoch - 445ms/step
# Epoch 6: early stopping

# %% [markdown]
# #### 2.4 Load the model

# %%
load_model_InceptionV3 = tf.keras.models.load_model('model_InceptionV3.h5')

# %% [markdown]
# #### 2.5 Evaluate the model

# %%
test_loss, test_accuracy = load_model_InceptionV3.evaluate(valid_generator)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
# Out:
# 2023-04-04 15:51:49.517610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 64/64 [==============================] - 6s 85ms/step - loss: 0.7589 - accuracy: 0.7905
# Test Loss: 0.7589378952980042, Test Accuracy: 0.7905206084251404

# %% [markdown]
# #### 2.6 Predict

# %%
prediction = np.argmax(load_model_InceptionV3.predict(valid_generator), axis = 1)
# Out:
# 2023-04-04 15:55:01.951210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 64/64 [==============================] - 6s 83ms/step

# %%
for image, label  in valid_generator:
    true_label = label
    true_image = image
    break

# %%
true_image_prediction = np.argmax(load_model_InceptionV3.predict(true_image[10:15]), axis = 1)
print(true_image_prediction)
# Out:
# 1/1 [==============================] - 1s 897ms/step
# [ 32  27  48  28 119]

# %%
index = np.where(true_label[10:15][0:5] == 1)[1]

# %%
index
# Out:
# array([ 32,  27,  48,  28, 119])

# %%
# tf.distribute.MirroredStrategy()
# strategy = tf.distribute.MirroredStrategy(["GPU:0", "GPU:1"])

# %% [markdown]
# # To build architecture from scratch
# ### 1.case

# %%
# class MyModel(Model):
#     def __init__(self):
#         super(MyModel, self).__init__()
#         self.conv1 = Conv2D(filters = 32, kernel_size = (3, 3), activation='relu', padding = 'same')
#         self.conv2 = Conv2D(filters = 64, kernel_size = (3, 3), activation='relu', padding = 'same')
#         self.conv3 = Conv2D(filters = 128, kernel_size = (3, 3), activation='relu', padding = 'same')
#         self.pooling = MaxPooling2D(pool_size = (2, 2), strides = 2)
#         self.flatten = Flatten()
#         self.d1 = Dense(1024, activation='relu')
#         self.d2 = Dense(512, activation='relu')
#         self.dense_output = Dense(120, activation = 'softmax')  

#     def call(self, x):
#         conv1_1 = self.conv1(x)
#         pool = self.pooling(conv1_1)
#         conv2_2 = self.conv2(pool)
#         pool = self.pooling(conv2_2)
#         conv3_3 = self.conv3(pool)
#         pool = self.pooling(conv3_3)
#         flatten_1  = self.flatten(pool)
#         hidden_1 = self.d1(flatten_1)
#         hidden_2 = self.d2(hidden_1)
#         return self.dense_output(hidden_2)

# # Create an instance of the model
# model = MyModel()

# %% [markdown]
# ### 2-case

# %%
# class MyModel(Model):
#     def __init__(self):
#         super(MyModel, self).__init__()
#         self.conv1 = Conv2D(96, 11,  activation='relu', strides = (4, 4),  padding = 'valid')
#         self.conv2 = Conv2D(256, 5, activation='relu', strides = (1, 1),  padding = 'same')
#         self.conv3 = Conv2D(384, 3, activation='relu', strides = (1, 1),  padding = 'same')
#         self.conv4 = Conv2D(384, 3, activation='relu', strides = (1, 1),  padding = 'same')
#         self.conv5 = Conv2D(384, 3, activation='relu', strides = (1, 1),  padding = 'same')
        
#         self.pooling = MaxPooling2D(pool_size = (2, 2), strides = (2, 2))
#         self.drop = Dropout(rate = 0.5)
#         self.flatten = Flatten()
#         self.d1 = Dense(4096, activation='relu')
#         self.d2 = Dense(4096, activation='relu')
#         self.dense_output = Dense(120, activation = 'softmax')  

#     def call(self, x):
#         conv1_1 = self.conv1(x)
#         pool = self.pooling(conv1_1)
#         dropout = self.drop(pool)

#         conv2_2 = self.conv2(dropout)
#         pool = self.pooling(conv2_2)
#         dropout = self.drop(pool)
        
#         conv3_3 = self.conv3(dropout)
#         conv4_4 = self.conv4(conv3_3)
#         conv5_5 = self.conv5(conv4_4)
#         pool = self.pooling(conv5_5)
#         dropout = self.drop(pool)
          
#         flatten_1  = self.flatten(dropout)
#         hidden_1 = self.d1(flatten_1)
#         hidden_2 = self.d2(hidden_1)
#         return self.dense_output(hidden_2)

# # Create an instance of the model
# model = MyModel()

# %% [markdown]
# ### 3-case
#
# #### 3.1 VGG19 architecture

# %%
class MyModel(Model):
    def __init__(self):
        super(MyModel, self).__init__()
        
        self.conv1 = Conv2D(64, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv1_1 = Conv2D(64, kernel_size = (3, 3),  activation='relu', padding = 'same')
        
        self.conv2 = Conv2D(128, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv2_1 = Conv2D(128, kernel_size = (3, 3),  activation='relu', padding = 'same')
        
        self.conv3 = Conv2D(256, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv3_1 = Conv2D(256, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv3_2 = Conv2D(256, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv3_3 = Conv2D(256, kernel_size = (3, 3),  activation='relu', padding = 'same')
        
        self.conv4 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv4_1 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv4_2 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv4_3 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        
        self.conv5 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv5_1 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv5_2 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        self.conv5_3 = Conv2D(512, kernel_size = (3, 3),  activation='relu', padding = 'same')
        
        self.pooling = MaxPooling2D(pool_size = (2, 2), strides = (2, 2), padding = 'same')
        
        self.drop = Dropout(rate = 0.2)
        self.flatten = Flatten()
#         self.dense1 = Dense(4096, activation='relu')
#         self.dense2 = Dense(2048, activation='relu')
        self.dense3 = Dense(1024, activation='relu')
#         self.dense4 = Dense(512, activation='relu')
        self.dense_output = Dense(120, activation = 'softmax')

    def call(self, x):
        
        # Block 1
        cnn1_1 = self.conv1(x)
        cnn1_2 = self.conv1_1(cnn1_1)
        pool = self.pooling(cnn1_2)

        
        #  Block 2
        cnn2_1 = self.conv2(pool)
        cnn2_2 = self.conv2_1(cnn2_1)
        pool = self.pooling(cnn2_2)
        
        # Block 3
        cnn3_1 = self.conv3(pool)
        cnn3_2 = self.conv3_1(cnn3_1)
        cnn3_3 = self.conv3_2(cnn3_2)
        cnn3_4 = self.conv3_3(cnn3_3)
        pool = self.pooling(cnn3_4)
        
        # Block 4
        cnn4_1 = self.conv4(pool)
        cnn4_2 = self.conv4_1(cnn4_1)
        cnn4_3 = self.conv4_2(cnn4_2)
        cnn4_4 = self.conv4_3(cnn4_3)
        pool = self.pooling(cnn4_4)
        
        # Block 5
        cnn5_1 = self.conv5(pool)
        cnn5_2 = self.conv5_1(cnn5_1)
        cnn5_3 = self.conv5_2(cnn5_2)
        cnn5_4 = self.conv5_3(cnn5_3)
        pool = self.pooling(cnn5_4)
        
        # Block 6   
        flatten_1  = self.flatten(pool)
#         hidden_1 = self.dense1(flatten_1) 
#         drop_1 = self.drop(hidden_1)
#         hidden_2 = self.dense2(drop_1)
#         drop_2 = self.drop(hidden_2)
        hidden_3 = self.dense3(flatten_1)
#         hidden_4 = self.dense4(hidden_3)
        return self.dense_output(hidden_3)

# Create an instance of the model
model = MyModel()

# %%
# To select the optimizer and loss
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam()

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')

# %%
# Define the checkpoint directory and file name
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

# Define the callback for saving the model
checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True)

# %% [markdown]
# #### 3.2 Train step

# %%
@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        # training=True is only needed if there are layers with different
        # behavior during training versus inference (e.g. Dropout).
        predictions = model(images, training=True)
        loss = loss_object(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)
    train_accuracy(labels, predictions)

# %% [markdown]
# #### 3.3 Test step

# %%
@tf.function
def test_step(images, labels):
    # training=False is only needed if there are layers with different
    # behavior during training versus inference (e.g. Dropout).
    predictions = model(images, training=False)
    t_loss = loss_object(labels, predictions)

    test_loss(t_loss)
    test_accuracy(labels, predictions)

# %% [markdown]
# #### 3.4 To fit the model

# %%
EPOCHS = 10

for epoch in range(EPOCHS):
    # Reset the metrics at the start of the next epoch
    train_loss.reset_states()
    train_accuracy.reset_states()
    test_loss.reset_states()
    test_accuracy.reset_states()
    
    for images, labels in train_ds:
        train_step(images, labels)

    for test_images, test_labels in val_ds:
        test_step(test_images, test_labels)
        
    # Save the model after each epoch
    model.save_weights(checkpoint_prefix.format(epoch=epoch)) 

    print(
    f'Epoch {epoch + 1}, '
    f'Loss: {train_loss.result()}, '
    f'Accuracy: {train_accuracy.result() * 100}, '
    f'Test Loss: {test_loss.result()}, '
    f'Test Accuracy: {test_accuracy.result() * 100}'
    )
# Out:
# Epoch 1, Loss: 8.599831581115723, Accuracy: 1.0386297702789307, Test Loss: 4.7828688621521, Test Accuracy: 1.0204081535339355
# Epoch 2, Loss: 4.822229862213135, Accuracy: 1.1904761791229248, Test Loss: 4.784078598022461, Test Accuracy: 1.0204081535339355
# Epoch 3, Loss: 4.781360149383545, Accuracy: 1.2755101919174194, Test Loss: 4.783656597137451, Test Accuracy: 1.0204081535339355
# Epoch 4, Loss: 4.780576229095459, Accuracy: 1.2755101919174194, Test Loss: 4.783255100250244, Test Accuracy: 1.0204081535339355
# Epoch 5, Loss: 4.780516147613525, Accuracy: 1.2755101919174194, Test Loss: 4.782993793487549, Test Accuracy: 1.0204081535339355
# Epoch 6, Loss: 4.7801361083984375, Accuracy: 1.2755101919174194, Test Loss: 4.783297061920166, Test Accuracy: 1.0204081535339355
# Epoch 7, Loss: 4.780270099639893, Accuracy: 1.2755101919174194, Test Loss: 4.7834062576293945, Test Accuracy: 1.0204081535339355
# Epoch 8, Loss: 4.780150890350342, Accuracy: 1.2755101919174194, Test Loss: 4.78366231918335, Test Accuracy: 1.0204081535339355
# Epoch 9, Loss: 4.77999210357666, Accuracy: 1.2755101919174194, Test Loss: 4.783754825592041, Test Accuracy: 1.0204081535339355
# Epoch 10, Loss: 4.78002405166626, Accuracy: 1.2755101919174194, Test Loss: 4.783885955810547, Test Accuracy: 1.0204081535339355

# %%
# Epoch 2, Loss: 20.1428165435791, Accuracy: 0.9961127042770386 for 1-case. This case is bad 
# Epoch 2, Loss: 4.781538486480713, Accuracy: 1.2633624076843262 for 2-case. 
# Epoch 30, Epoch 30, Loss: 4.778024196624756, Accuracy: 1.2876579761505127 for 2-case.

# %%
model.summary()
# Out:
# Model: "my_model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_362 (Conv2D)         multiple                  1792
#
#  conv2d_363 (Conv2D)         multiple                  36928
#
#  conv2d_364 (Conv2D)         multiple                  73856
#
#  conv2d_365 (Conv2D)         multiple                  147584
#
#  conv2d_366 (Conv2D)         multiple                  295168
#
#  conv2d_367 (Conv2D)         multiple                  590080
#
#  conv2d_368 (Conv2D)         multiple                  590080
#
#  conv2d_369 (Conv2D)         multiple                  590080
#
#  conv2d_370 (Conv2D)         multiple                  1180160
#
#  conv2d_371 (Conv2D)         multiple                  2359808
#
#  conv2d_372 (Conv2D)         multiple                  2359808
#
#  conv2d_373 (Conv2D)         multiple                  2359808
#
#  conv2d_374 (Conv2D)         multiple                  2359808
#
#  conv2d_375 (Conv2D)         multiple                  2359808
#
#  conv2d_376 (Conv2D)         multiple                  2359808
#
#  conv2d_377 (Conv2D)         multiple                  2359808
#
#  max_pooling2d_17 (MaxPoolin  multiple                 0
#  g2D)
#
#  dropout_10 (Dropout)        multiple                  0 (unused)
#
#  flatten_6 (Flatten)         multiple                  0
#
#  dense_17 (Dense)            multiple                  25691136
#
#  dense_18 (Dense)            multiple                  123000
#
# =================================================================
# Total params: 45,838,520
# Trainable params: 45,838,520
# Non-trainable params: 0
# _________________________________________________________________

# %%
os.listdir('./training_checkpoints')
# Out:
# ['ckpt_8.index',
#  'ckpt_1.index',
#  'ckpt_1.data-00000-of-00001',
#  'ckpt_2.data-00000-of-00001',
#  'ckpt_0.index',
#  'ckpt_4.data-00000-of-00001',
#  'ckpt_5.index',
#  'ckpt_8.data-00000-of-00001',
#  'ckpt_2.index',
#  'ckpt_6.index',
#  'ckpt_4.index',
#  'ckpt_3.index',
#  'checkpoint',
#  'ckpt_5.data-00000-of-00001',
#  'ckpt_3.data-00000-of-00001',
#  'ckpt_9.data-00000-of-00001',
#  'ckpt_7.index',
#  'ckpt_9.index',
#  'ckpt_7.data-00000-of-00001',
#  'ckpt_6.data-00000-of-00001',
#  'ckpt_0.data-00000-of-00001']

# %%
# Restore the latest checkpoint
latest_checkpoint = tf.train.latest_checkpoint('./training_checkpoints')
if latest_checkpoint:
    print(model.load_weights(latest_checkpoint))
# Out:
# <tensorflow.python.checkpoint.checkpoint.CheckpointLoadStatus object at 0x7f75c1f964c0>

# %%
# save the model in SavedModel format as tf 
model.save('my_model', save_format='tf')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f7602729820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.regularization.dropout.Dropout object at 0x7f7602729820>, because it is not built.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 16). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_model/assets
# INFO:tensorflow:Assets written to: my_model/assets

# %%
# load the model
loaded_model = tf.keras.models.load_model('my_model')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
a = loaded_model.predict(val_ds)
# Out:
# 65/65 [==============================] - 13s 196ms/step

# %%
np.argmax(a, axis = 1)

# %%
k = loaded_model.predict(image_batch[0:1])

# %%
np.argmax(k, axis = 1)
